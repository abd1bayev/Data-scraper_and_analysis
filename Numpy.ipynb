# %% [markdown]
# <a href="https://colab.research.google.com/github/abd1bayev/Data_screper/blob/master/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Ilmiy hisoblash uchun asosiy paketlardan biri ekanligini hisobga olsak, NumPy siz Python bilan maʼlumotlar fanini oʻrganishni xohlaysizmi yoki yoʻqligini bilishingiz kerak boʻlgan paketlardan biridir. U Python roʻyxatlariga ajoyib muqobil taklif etadi, chunki NumPy massivlari ixchamroq boʻlib, elementlarni oʻqish va yozishda tezroq kirish imkonini beradi va umuman olganda qulayroq va samaraliroqdir. ***
#
# # ***Bundan tashqari, bu (qisman) ma'lumotlarni manipulyatsiya qilish va mashinani o'rganish uchun ishlatiladigan boshqa muhim paketlarning asosi bo'lib, siz allaqachon bilishingiz mumkin, xususan, Pandas, Scikit-Learn va SciPy:***
#
# # ***Pandas ma'lumotlarini boshqarish kutubxonasi NumPy-ga asoslanadi, lekin massivlar o'rniga u boshqa ikkita asosiy ma'lumotlar tuzilmalaridan foydalanadi: Series va DataFrames,***
# # ***SciPy NumPy massivlarida ishlaydigan ko'p sonli funktsiyalarni ta'minlash uchun Numpy-ga asoslanadi va***
# # ***Scikit-Learn mashina o'rganish kutubxonasi nafaqat NumPy, balki SciPy va Matplotlib-da ham quriladi. ***
#
#
# # ***Ko'ryapsizmi, bu Python kutubxonasi bilishi shart: agar siz u bilan qanday ishlashni bilsangiz, siz shubhasiz foydalanadigan Python ma'lumotlar fanining boshqa vositalarini ham yaxshiroq tushunasiz. ***
#
# # ***Bu g'alaba qozongan vaziyat, to'g'rimi?***
#
# # ***Shunga qaramay, har qanday boshqa kutubxona singari, NumPy ham boshidan juda hayratlanarli bo'lib chiqishi mumkin; Ushbu ma'lumotlarni tahlil qilish kutubxonasidan foydalanishni boshlash uchun qanday asoslarni bilishingiz kerak?***
#
# # ***Ushbu cheat varaq sizga ushbu kutubxona taklif qiladigan imkoniyatlar haqida yaxshi ma'lumot berishni anglatadi. ***

# %% [markdown]
# ![Screen_Shot_2021-10-18_at_8.27.05_PM_nweo4x.webp](data:image/webp;base64,...)

# %% [markdown]
# # ***Siz ushbu hiyla-nayrang varaqasi siz boshlashingiz kerak bo'lgan NumPy asoslarini qamrab olishini ko'rasiz: u Python kutubxonasi nimani taklif qilishi va massiv ma'lumotlar tuzilmasi qanday ko'rinishi haqida qisqacha tushuntirish beradi va shu kabi mavzularni sarhisob qiladi. massiv yaratish, kiritish-chiqarish, massivni tekshirish, massiv matematikasi, massivlarni nusxalash va saralash, massiv elementlarini tanlash va shaklni manipulyatsiya qilish.***
#
# # ***NumPy massivlari ko'pincha Python ro'yxatidan afzalroqdir va siz massivlardan elementlarni tanlash ro'yxatlardan elementlarni tanlashga juda o'xshashligini ko'rasiz.***
#
# # ***Ko'proq bilishni xohlaysizmi? DataCamp-ning  Python ro'yxati bo'yicha o'quv qo'llanmasini ko'rib chiqing. ***
#
# # ***PS. Scikit-Learn ,  Bokeh , Pandas va Python asoslarini  qamrab olgan maʼlumotlar faniga oid boshqa Python cheat cheatlarimizni oʻtkazib yubormang  .***
#
# # ***NumPy***
#
# # ***NumPy kutubxonasi Pythonda ilmiy hisoblash uchun asosiy kutubxona hisoblanadi. U yuqori unumli ko'p o'lchovli massiv ob'ektini va ushbu massivlar bilan ishlash vositalarini taqdim etadi.  ***
#
# # ***Quyidagi improt konventsiyasidan foydalaning:  ***

# %%
import numpy as np

# %% [markdown]
# # ***Numpy massivlar ***
# ![array_2a1fcdf391.png](data:image/png;base64,...)
# # ***Massivlarni yaratish ***

# %%
a = np.array([1,2,3])
b = np.array([(1.5,2,3), (4,5,6)], dtype = float)
c = np.array([[(1.5,2,3), (4,5,6)],[(3,2,1), (4,5,6)]], dtype = float)

# %% [markdown]
# # ***Boshlang'ich to'ldiruvchilar ***

# %%
np.zeros((3,4)) #Nollardan iborat massiv yarating

# %%
np.ones((2,3,4),dtype=np.int16) #Birlar qatorini yarating

# %%
d = np.arange(10,25,5) #Teng oraliqli qiymatlar massivini yarating (qadam qiymati)
d

# %%
np.linspace(0,2,9) #Teng intervalli qiymatlar qatorini yarating (namunalar soni)

# %%
e = np.full((2,2),7) #Doimiy massiv yarating
e

# %%
f = np.eye(2) #2X2 identifikatsiya matritsasi yarating
f

# %%
np.random.random((2,2)) #Tasodifiy qiymatlar bilan massiv yarating

# %%
np.empty((3,2)) #Bo'sh massiv yarating

# %% [markdown]
# # ***I/U***
# # Diskda saqlash va *yuklash*

# %%
np.save('my_array', a)
np.savez('array.npz', a, b)
np.load('my_array.npy')
# Out:
# array([1, 2, 3])

# %% [markdown]
# # ***Matn fayllarini saqlash va yuklash ***

# %%
np.loadtxt("myfile.txt")
np.genfromtxt("my_file.csv", delimiter=',')
np.savetxt("myarray.txt", a, delimiter=" ")

# %% [markdown]
# # ***Yordam so'rash ***

# %%
np.info(np.ndarray.dtype)
# Out:
# Data-type of the array's elements.
#
# Parameters
# ----------
# None
#
# Returns
# -------
# d : numpy dtype object
#
# See Also
# --------
# numpy.dtype
#
# Examples
# --------
# >>> x
# array([[0, 1],
#        [2, 3]])
# >>> x.dtype
# dtype('int32')
# >>> type(x.dtype)
# <type 'numpy.dtype'>

# %% [markdown]
# # ***Massivingizni tekshirish ***

# %%
a.shape #Masiv o'lchamlari
# Out:
# (3,)

# %%
len(a) #Masiv uzunligi
# Out:
# 3

# %%
b.ndim #Masiv o'lchamlari soni
# Out:
# 2

# %%
e.size #Masiv elementlari soni
# Out:
# 4

# %%
b.dtype #Masiv elementlarining ma'lumotlar turi
# Out:
# dtype('float64')

# %%
b.dtype.name #Ma'lumotlar turi nomi
# Out:
# 'float64'

# %%
b.astype(int) #Masivni boshqa turga aylantirish
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# # *Ma'lumotlar turlari*

# %%
np.int64 #Imzolangan 64 bitli tamsayı turlari
# Out:
# numpy.int64

# %%
np.float32 #Standart ikki aniqlikdagi suzuvchi nuqta
# Out:
# numpy.float32

# %%
np.complex #128 ta suzuvchi bilan ifodalangan murakkab raqamlar
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# complex

# %%
np.bool #TRUE va FALSE qiymatlarini saqlaydigan mantiqiy turi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# bool

# %%
np.object #Python ob'ekt turi
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# object

# %%
np.string_ #Fixed-length string type
# Out:
# numpy.bytes_

# %%
np.unicode_ # Ruxsat etilgan uzunlikdagi unicode turi
# Out:
# numpy.str_

# %% [markdown]
# # ***Massiv matematikasi***
# # Arifmetik amallar`

# %%
g = a - b #ayirish
np.subtract(a,b) #ayirish
# Out:
# array([[-0.5,  0. ,  0. ],
#        [-3. , -3. , -3. ]])

# %%
b + a #Qo'shimcha
np.add(b,a) #Qo'shimcha
# Out:
# array([[2.5, 4. , 6. ],
#        [5. , 7. , 9. ]])

# %%
a/b #bo'lish
np.divide(a,b) #bo'lish
# Out:
# array([[0.66666667, 1.        , 1.        ],
#        [0.25      , 0.4       , 0.5       ]])

# %%
a * b #Ko'paytirish
np.multiply(a,b) #Ko'paytirish
# Out:
# array([[ 1.5,  4. ,  9. ],
#        [ 4. , 10. , 18. ]])

# %%
np.exp(b) #Ko'rsatkich
# Out:
# array([[  4.48168907,   7.3890561 ,  20.08553692],
#        [ 54.59815003, 148.4131591 , 403.42879349]])

# %%
np.sqrt(b) #Kvadrat ildiz
# Out:
# array([[1.22474487, 1.41421356, 1.73205081],
#        [2.        , 2.23606798, 2.44948974]])

# %%
np.sin(a) #Masivning sinuslarini chop etish
# Out:
# array([0.84147098, 0.90929743, 0.14112001])

# %%
np.cos(b) #Elementli kosinus
# Out:
# array([[ 0.0707372 , -0.41614684, -0.9899925 ],
#        [-0.65364362,  0.28366219,  0.96017029]])

# %%
np.log(a) #Elementlar boʻyicha natural logarifm
# Out:
# array([0.        , 0.69314718, 1.09861229])

# %%
e.dot(f) #Nuqta mahsuloti
# Out:
# array([[7., 7.],
#        [7., 7.]])

# %% [markdown]
# # ***Comparison ***

# %%
a == b #Element bo'yicha taqqoslash
# Out:
# array([[False,  True,  True],
#        [False, False, False]])

# %%
a< 2 #Element bo'yicha taqqoslash
# Out:
# array([ True, False, False])

# %%
np.array_equal(a, b) #Masiv bo'yicha taqqoslash
# Out:
# False

# %% [markdown]
# # ***Massivlardan nusxa olish***

# %%
h = a.view() #Bir xil ma'lumotlar bilan massiv ko'rinishini yarating
h
# Out:
# array([1, 2, 3])

# %%
np.copy(a) #Masiv nusxasini yarating
# Out:
# array([1, 2, 3])

# %%
h = a.copy() #Masivning chuqur nusxasini yarating
h
# Out:
# array([1, 2, 3])

# %% [markdown]
# # ***Massivlarni saralash***

# %%
a.sort() #Masivni saralash
a
# Out:
# array([1, 2, 3])

# %%
c.sort(axis=0) #Masiv o'qi elementlarini saralash
c
# Out:
# array([[[1.5, 2. , 1. ],
#         [4. , 5. , 6. ]],
#
#        [[3. , 2. , 3. ],
#         [4. , 5. , 6. ]]])

# %% [markdown]
# # ***O'rnatish, kesish, indekslash***
# # O'rnatish

# %%
a[2] #2-indeksdagi elementni tanlang
# Out:
# 3

# %%
b[1,2] #1-qator 2-ustundagi elementni tanlang(b[1][2] ga ekvivalent)
# Out:
# 6.0

# %% [markdown]
# # **Kesish**

# %%
a[0:2] #0 va 1 indeksidagi elementlarni tanlang
# Out:
# array([1, 2])

# %%
b[0:2,1] #1-ustunda 0 va 1-qatorlardagi elementlarni tanlang
# Out:
# array([2., 5.])

# %%
b[:1] #0-qatordagi barcha elementlarni tanlang(b[0:1, :] ga ekvivalent)
# Out:
# array([[1.5, 2. , 3. ]])

# %%
c[1,...] #Xuddi[1,:,:]
# Out:
# array([[3., 2., 3.],
#        [4., 5., 6.]])

# %%
a[ : : -1] #Teskari massiv
# Out:
# array([3, 2, 1])

# %% [markdown]
# # ***Mantiqiy indekslash***

# %%
a[a<2] #2 dan kichik elementlardan tanlang
# Out:
# array([1])

# %% [markdown]
# # ***Fantastik indekslash***

# %%
b[[1,0,1, 0],[0,1,2,0]] #Elementlarni tanlang(1,0),(0,1),(1,2) va(0,0)
# Out:
# array([4. , 2. , 6. , 1.5])

# %%
b[[1,0,1,0]][:,[0,1,2,0]] #Matritsaning satr va ustunlari toʻplamini tanlang
# Out:
# array([[4. , 5. , 6. , 4. ],
#        [1.5, 2. , 3. , 1.5],
#        [4. , 5. , 6. , 4. ],
#        [1.5, 2. , 3. , 1.5]])

# %% [markdown]
# # ***Massiv manipulyatsiyasi***
# # *Transposing Array *

# %%
i = np.transpose(b) #Masiv oʻlchamlarini oʻzgartirish
i
# Out:
# array([[1.5, 4. ],
#        [2. , 5. ],
#        [3. , 6. ]])

# %%
i.T #Masiv oʻlchamlarini oʻzgartirish
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %% [markdown]
# #Massiv shaklini o'zgartirish*

# %%
b.ravel() #Masivni tekislang
# Out:
# array([1.5, 2. , 3. , 4. , 5. , 6. ])

# %%
g.reshape(3, -2) #Qayta shakllantiring, lekin maʼlumotlarni oʻzgartirmang
# Out:
# array([[-0.5,  0. ],
#        [ 0. , -3. ],
#        [-3. , -3. ]])

# %% [markdown]
# # *Elementlarni qo'shish/o'chirish *

# %%
np.append(h,g) #Masivga elementlarni qo'shish
# Out:
# array([ 1. ,  2. ,  3. , -0.5,  0. ,  0. , -3. , -3. , -3. ])

# %%
np.insert(a, 1,5) #Masivga elementlarni kiritish
# Out:
# array([1, 5, 2, 3])

# %%
np.delete(a,[1]) #Masivdagi elementlarni oʻchirish
# Out:
# array([1, 3])

# %% [markdown]
# # *Massivlarni birlashtirish*

# %%
np.concatenate((a,d),axis=0) #Masivlarni birlashtirish
# Out:
# array([ 1,  2,  3, 10, 15, 20])

# %%
np.vstack((a,b)) #Masivlarni vertikal ravishda to'plash (qator bo'yicha)
# Out:
# array([[1. , 2. , 3. ],
#        [1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
np.r_[e,f] #Masivlarni vertikal ravishda to'plash (qator bo'yicha)
# Out:
# array([[7., 7.],
#        [7., 7.],
#        [1., 0.],
#        [0., 1.]])

# %%
np.hstack((e,f)) #Massivlarni gorizontal ravishda yig'ish (ustun bo'yicha)
# Out:
# array([[7., 7., 1., 0.],
#        [7., 7., 0., 1.]])

# %%
np.column_stack((a,d)) #Yig'ilgan ustunli massivlarni yarating
# Out:
# array([[ 1, 10],
#        [ 2, 15],
#        [ 3, 20]])

# %%
np.c_[a,d] #Yig'ilgan ustunli massivlarni yarating
# Out:
# array([[ 1, 10],
#        [ 2, 15],
#        [ 3, 20]])

# %% [markdown]
# # *Massivlarni ajratish*

# %%
np.hsplit(a,3) #3-indeksda massivni gorizontal ravishda ajrating
# Out:
# [array([1]), array([2]), array([3])]

# %%
np.vsplit(c,2) ##Masivni vertikal ravishda 2-indeksga ajrating
# Out:
# [array([[1.5, 2. , 1. , 4. , 5. , 6. ]]), array([[3., 2., 3., 4., 5., 6.]])]

# %% [markdown]
# # ***Thank you all***
#
# ---
